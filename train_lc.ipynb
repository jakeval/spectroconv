# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# ENABLE IF USING COLAB
USE_COLAB = True

if USE_COLAB:
    import os
    from google.colab import drive
    
    FOLDERNAME = 'UMass_Amherst/NN_AMI/NN_Project'
    drive.mount('/content/drive')
    # %cd /content/drive/My\ Drive/$FOLDERNAME

    if os.path.exists('./spectroconv/'):
      # %cd ./spectroconv
      # !pip install hub
      # !pip install hub[audio]
      # !pip install wandb
    else:
      print("Error, must first pull project repository from github to Drive using ColabGitCommands.ipynb")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/UMass_Amherst/NN_AMI/NN_Project
# /content/drive/My Drive/UMass_Amherst/NN_AMI/NN_Project/spectroconv
# Requirement already satisfied: hub in /usr/local/lib/python3.7/dist-packages (2.4.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from hub) (7.1.2)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from hub) (7.1.2)
# Requirement already satisfied: humbug>=0.2.6 in /usr/local/lib/python3.7/dist-packages (from hub) (0.2.7)
# Requirement already satisfied: pathos in /usr/local/lib/python3.7/dist-packages (from hub) (0.2.8)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from hub) (4.64.0)
# Requirement already satisfied: numcodecs in /usr/local/lib/python3.7/dist-packages (from hub) (0.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hub) (1.21.6)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (from hub) (1.22.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from humbug>=0.2.6->hub) (2.23.0)
# Requirement already satisfied: botocore<1.26.0,>=1.25.3 in /usr/local/lib/python3.7/dist-packages (from boto3->hub) (1.25.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3->hub) (1.0.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from boto3->hub) (0.5.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.7/dist-packages (from botocore<1.26.0,>=1.25.3->boto3->hub) (1.25.11)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.26.0,>=1.25.3->boto3->hub) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.26.0,>=1.25.3->boto3->hub) (1.15.0)
# Requirement already satisfied: ppft>=1.6.6.4 in /usr/local/lib/python3.7/dist-packages (from pathos->hub) (1.6.6.4)
# Requirement already satisfied: multiprocess>=0.70.12 in /usr/local/lib/python3.7/dist-packages (from pathos->hub) (0.70.12.2)
# Requirement already satisfied: dill>=0.3.4 in /usr/local/lib/python3.7/dist-packages (from pathos->hub) (0.3.4)
# Requirement already satisfied: pox>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from pathos->hub) (0.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->humbug>=0.2.6->hub) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->humbug>=0.2.6->hub) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->humbug>=0.2.6->hub) (3.0.4)
# Requirement already satisfied: hub[audio] in /usr/local/lib/python3.7/dist-packages (2.4.0)
# Requirement already satisfied: numcodecs in /usr/local/lib/python3.7/dist-packages (from hub[audio]) (0.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hub[audio]) (1.21.6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from hub[audio]) (7.1.2)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (from hub[audio]) (1.22.3)
# Requirement already satisfied: pathos in /usr/local/lib/python3.7/dist-packages (from hub[audio]) (0.2.8)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from hub[audio]) (7.1.2)
# Requirement already satisfied: humbug>=0.2.6 in /usr/local/lib/python3.7/dist-packages (from hub[audio]) (0.2.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from hub[audio]) (4.64.0)
# Requirement already satisfied: av>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from hub[audio]) (9.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from humbug>=0.2.6->hub[audio]) (2.23.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from boto3->hub[audio]) (0.5.2)
# Requirement already satisfied: botocore<1.26.0,>=1.25.3 in /usr/local/lib/python3.7/dist-packages (from boto3->hub[audio]) (1.25.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3->hub[audio]) (1.0.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.26.0,>=1.25.3->boto3->hub[audio]) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.7/dist-packages (from botocore<1.26.0,>=1.25.3->boto3->hub[audio]) (1.25.11)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.26.0,>=1.25.3->boto3->hub[audio]) (1.15.0)
# Requirement already satisfied: multiprocess>=0.70.12 in /usr/local/lib/python3.7/dist-packages (from pathos->hub[audio]) (0.70.12.2)
# Requirement already satisfied: dill>=0.3.4 in /usr/local/lib/python3.7/dist-packages (from pathos->hub[audio]) (0.3.4)
# Requirement already satisfied: ppft>=1.6.6.4 in /usr/local/lib/python3.7/dist-packages (from pathos->hub[audio]) (1.6.6.4)
# Requirement already satisfied: pox>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from pathos->hub[audio]) (0.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->humbug>=0.2.6->hub[audio]) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->humbug>=0.2.6->hub[audio]) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->humbug>=0.2.6->hub[audio]) (3.0.4)
# Requirement already satisfied: wandb in /usr/local/lib/python3.7/dist-packages (0.12.15)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.0.8)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.7/dist-packages (from wandb) (1.2.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.7/dist-packages (from wandb) (0.1.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.2)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.1.27)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.5.10)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.2.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb) (5.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)

# %%
import torch
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri Apr 29 08:33:11 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from models import wb_experiment

# %%
n_mels = 128
wb_config = {
    'project': 'spectroconv-debug',
    'entity': 'jakeval-colab',
    'group': 'lc' # use this only when training/evaluating/etc a CNN
}

config = {
    'data': {
        'train': {
            'name': f'nsynth-full-{n_mels}-train'
        },
        'val': {
            'name': f'nsynth-full-{n_mels}-val'
        }
    },
    'model': {
        'id': wb_experiment.ModelType.LC,
        'name': 'LC'
    },
    'logging': {
        'batch_log_interval': 250,
        'eval_every_batch': True,
        'eval_every_epoch': True,
    },
    'parameters': {
      'epochs': 3,
      'batch_size': 100,
      'optimizer': 'adam',
      'learning_rate': 0.0005,
      'dropout': 0.5, # probability of an element to be zeroed (0 = no dropout)
      'l2_reg': 0,
      'kernel_size': 5,
      'num_channels': 16,
      'num_conv_layers': 1,
      'linear_layer_size': 64,
    },
    },
}

# %%
trainer = wb_experiment.TrainExperiment(wb_config=wb_config, login_key=True)
trainer.run_train(config, save_model=False)
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/drive/MyDrive/UMass_Amherst/NN_AMI/NN_Project/spectroconv/wandb/run-20220429_090827-34ojsptv</code>
# Syncing run <strong><a href="https://wandb.ai/jakeval-colab/spectroconv-debug/runs/34ojsptv" target="_blank">fluent-wildflower-290</a></strong> to <a href="https://wandb.ai/jakeval-colab/spectroconv-debug" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: WARNING A graphql request initiated by the public wandb API timed out (timeout=9 sec). Create a new API with an integer timeout larger than 9, e.g., `api = wandb.Api(timeout=19)` to increase the graphql timeout.
# hub://jakeval/nsynth-full-128-train-metadata loaded successfully.
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/jakeval/nsynth-full-128-train-metadata
# hub://jakeval/nsynth-full-128-train loaded successfully.
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/jakeval/nsynth-full-128-train
# hub://jakeval/nsynth-full-128-val-metadata loaded successfully.
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/jakeval/nsynth-full-128-val-metadata
# hub://jakeval/nsynth-full-128-val loaded successfully.
# This dataset can be visualized in Jupyter Notebook by ds.visualize() or at https://app.activeloop.ai/jakeval/nsynth-full-128-val
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/1452 [00:00<?, ?it/s]
# Batch 0: Loss: 1.5982, Accuracy: 0.2700
# Split: val, Loss: 6885.23, Accuracy: 0.3454, F1: 0.1891
# Batch 250: Loss: 0.6939, Accuracy: 0.6183
# Split: val, Loss: 17647.77, Accuracy: 0.5731, F1: 0.5479
# Batch 500: Loss: 0.6070, Accuracy: 0.7191
# Split: val, Loss: 20797.55, Accuracy: 0.5882, F1: 0.5664
# Batch 750: Loss: 0.6234, Accuracy: 0.7577
# Split: val, Loss: 22569.17, Accuracy: 0.5975, F1: 0.5725
# Batch 1000: Loss: 0.5079, Accuracy: 0.7820
# Split: val, Loss: 25520.71, Accuracy: 0.5871, F1: 0.5710
# Batch 1250: Loss: 0.9059, Accuracy: 0.7947
# Split: val, Loss: 28052.22, Accuracy: 0.6121, F1: 0.6057
# Split: val, Epoch: 0, Loss: 30119.62, Accuracy: 0.5930, F1: 0.5651
#   0%|          | 0/1452 [00:00<?, ?it/s]
# Batch 0: Loss: 0.4116, Accuracy: 0.8026
# Split: val, Loss: 31162.35, Accuracy: 0.5810, F1: 0.5470
# Batch 250: Loss: 0.4596, Accuracy: 0.8139
# Split: val, Loss: 29131.92, Accuracy: 0.6379, F1: 0.6165
# Batch 500: Loss: 0.4165, Accuracy: 0.8184
# Split: val, Loss: 28885.46, Accuracy: 0.6535, F1: 0.6362
# Batch 750: Loss: 0.4500, Accuracy: 0.8251
# Split: val, Loss: 33494.08, Accuracy: 0.6032, F1: 0.5929
# Batch 1000: Loss: 0.2889, Accuracy: 0.8295
# Split: val, Loss: 34544.82, Accuracy: 0.6481, F1: 0.6209
# Batch 1250: Loss: 0.4313, Accuracy: 0.8350
# Split: val, Loss: 30954.03, Accuracy: 0.6494, F1: 0.6389
# Split: val, Epoch: 1, Loss: 36108.91, Accuracy: 0.6391, F1: 0.6234
#   0%|          | 0/1452 [00:00<?, ?it/s]
# Batch 0: Loss: 0.4367, Accuracy: 0.8408
# Split: val, Loss: 35586.17, Accuracy: 0.6397, F1: 0.6253
# Batch 250: Loss: 0.2985, Accuracy: 0.8467
# Split: val, Loss: 31143.69, Accuracy: 0.6652, F1: 0.6365
# Batch 500: Loss: 0.3218, Accuracy: 0.8481
# Split: val, Loss: 33216.17, Accuracy: 0.6571, F1: 0.6448
# Batch 750: Loss: 0.4847, Accuracy: 0.8500
# Split: val, Loss: 31812.45, Accuracy: 0.6621, F1: 0.6471
# Batch 1000: Loss: 0.3104, Accuracy: 0.8520
# Split: val, Loss: 36023.79, Accuracy: 0.6536, F1: 0.6288
# Batch 1250: Loss: 0.2816, Accuracy: 0.8533
# Split: val, Loss: 41103.42, Accuracy: 0.6497, F1: 0.6310
# Split: val, Epoch: 2, Loss: 37900.89, Accuracy: 0.6652, F1: 0.6565
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▆▆▇▆▇▆▆▇█▇██▇▇██████</td></tr><tr><td>epoch</td><td>▁▅█</td></tr><tr><td>f1</td><td>▁▆▇▇▇▇▇▆▇█▇▇█████████</td></tr><tr><td>loss</td><td>▁▃▄▄▅▅▆▆▆▆▆▇▆▇▇▆▆▆▇█▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.66523</td></tr><tr><td>epoch</td><td>2</td></tr><tr><td>f1</td><td>0.65651</td></tr><tr><td>loss</td><td>37900.89062</td></tr><tr><td>split</td><td>val</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">fluent-wildflower-290</strong>: <a href="https://wandb.ai/jakeval-colab/spectroconv-debug/runs/34ojsptv" target="_blank">https://wandb.ai/jakeval-colab/spectroconv-debug/runs/34ojsptv</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220429_090827-34ojsptv/logs</code>
# LcClf(
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (convs): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(6, 6), stride=(1, 1), padding=same)
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout2d(p=0.5, inplace=False)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (lc_layer): LocallyConnectedConv()
#   (fc1): Linear(in_features=35840, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=5, bias=True)
# )
